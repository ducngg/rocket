# %% [markdown]
# # Set up

# %%
import os
import shutil
import time
import sys
import json

# %%
import os
HOME = os.getcwd()

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# change "/content/gdrive/MyDrive/"  to "/mydrive so you can use directly /mydrive"
# !ln -s /content/gdrive/MyDrive/ /mydrive
# Out:
# Mounted at /content/gdrive

# %%
import shutil

# %%
# print(len(os.listdir('heineken-images')))

# %% [markdown]
# # Deploy ResNet50

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from PIL import Image
import os
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load pre-trained ResNet50 model
resnet50 = models.resnet50(pretrained=True).to(device)
resnet50.eval()

# Remove the last layer (classification layer)
model = nn.Sequential(*list(resnet50.children())[:-1]).to(device)
model.eval()

# Define image preprocessing
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 116MB/s]

# %%
def preprocess_image(image_path):
    image = Image.open(image_path).convert("RGB")
    image = preprocess(image).unsqueeze(0).to(device)

    # torch.Tensor (1, C, W, H)
    return image

def get_embedding(image_path):
    image = preprocess_image(image_path)
    with torch.no_grad():
        embedding = model(image).cpu().numpy().flatten()

    # numpy.ndarray (1 dim)
    return embedding

# %% [markdown]
# # Vector DB

# %%
from collections import Counter
import sys, time, os
from dataclasses import dataclass, field
from typing import List, Tuple
from pydantic import BaseModel
import numpy as np
import pickle

@dataclass
class Record:
    source: str
    brand: str
    vector: np.ndarray

class VectorDatabase:
    def __init__(self):
        self.db = {
            "bottle": [],
            "can": [],
            "carton": [],
            "icebox": [],
            "icebucket": [],
            "standee": [],
            "banner": []
        }

    def add(self, filepath: str):
        filename = os.path.basename(filepath)
        if filename in [".DS_Store", ".ipynb_checkpoints"]:
            return

        # tiger.can.1.png
        brand, type, no, _ = filename.split('.')
        vector = get_embedding(filepath)

        if type == "logo":
            for key in self.db.keys():
                self.db[key].append(
                    Record(filepath, brand, vector)
                )
        else:
            if type not in self.db.keys():
                raise ValueError(f"Invalid type: {type}")
            self.db[type].append(
                Record(filepath, brand, vector)
            )

    def brand(self, type, vector, threshold: float = 0.5, top_k: int = 5) -> str:
        query_vector = vector.reshape(1, -1)  # Encode -> 2D array
        record_vectors = np.array([record.vector for record in self.db[type]])

        similarities = cosine_similarity(query_vector, record_vectors).flatten()
        top_indices: List[int] = similarities.argsort()[::-1]

        brand = self.db[type][top_indices[0]].brand

        # Filter out indices with similarity below the threshold
        top_indices = [idx for idx in top_indices if similarities[idx] > threshold]

        if not top_indices:
            return None  # No similar vectors above the threshold

        # Get the top_k indices
        top_k_indices = top_indices[:top_k]

        for idx in top_k_indices:
            print(similarities[idx], self.db[type][idx].brand, self.db[type][idx].source)

        # Get the brands of the top_k most similar vectors
        top_k_brands = [self.db[type][idx].brand for idx in top_k_indices]

        # Determine the most common brand using majority vote
        most_common_brand, _ = Counter(top_k_brands).most_common(1)[0]

        return most_common_brand

# %%
BASE_FOLDER = '/mydrive/base'

# %%
BRANDS = os.listdir(BASE_FOLDER)
BRANDS
# Out:
# ['.DS_Store',
#  'biaviet',
#  'tiger',
#  'larue',
#  'edelweiss',
#  'bivina',
#  'strongbow',
#  'heineken']

# %%
db = VectorDatabase()

# %% [markdown]
# Embed images

# %%
for brand in BRANDS:
    if brand == '.DS_Store':
        continue
    for filename in os.listdir(os.path.join(BASE_FOLDER, brand)):
        filepath = os.path.join(BASE_FOLDER, brand, filename)
        db.add(filepath)

# %%
import pickle as pkl
with open('vdb.pkl', 'wb') as f:
    pkl.dump(db, f)

# %%
TEST_FOLDER = '/mydrive/brands-tests'

# %%
test_records = []

for filename in os.listdir(TEST_FOLDER):
    true_brand, type,  *_ = filename.split('.')
    filepath = os.path.join(TEST_FOLDER, filename)
    brand = db.brand(type, get_embedding(filepath), top_k=5)

    test_records.append(
        (true_brand==brand, type, true_brand, brand, filepath)
    )
    print(f"EXPECTED: {true_brand:<20}GOT: {brand}")
# Out:
# 0.9999999 tiger /mydrive/base/tiger/tiger.bottle.14.png
# 0.88013136 tiger /mydrive/base/tiger/tiger.bottle.12.png
# 0.8502703 tiger /mydrive/base/tiger/tiger.bottle.1.png
# 0.8298529 tiger /mydrive/base/tiger/tiger.bottle.6.png
# 0.8037513 tiger /mydrive/base/tiger/tiger.bottle.2.png
# EXPECTED: tiger               GOT: tiger
# 0.9999999 tiger /mydrive/base/tiger/tiger.bottle.1.png
# 0.87543255 tiger /mydrive/base/tiger/tiger.bottle.2.png
# 0.8502703 tiger /mydrive/base/tiger/tiger.bottle.14.png
# 0.8348228 tiger /mydrive/base/tiger/tiger.bottle.12.png
# 0.7963221 tiger /mydrive/base/tiger/tiger.bottle.6.png
# EXPECTED: tiger               GOT: tiger
# 0.81426775 tiger /mydrive/base/tiger/tiger.bottle.14.png
# 0.7876244 biaviet /mydrive/base/biaviet/biaviet.bottle.5.png
# 0.78752494 tiger /mydrive/base/tiger/tiger.bottle.12.png
# 0.7867473 tiger /mydrive/base/tiger/tiger.bottle.1.png
# 0.77587634 tiger /mydrive/base/tiger/tiger.bottle.3.png
# EXPECTED: edelweiss           GOT: tiger
# 1.0000002 tiger /mydrive/base/tiger/tiger.carton.10.png
# 0.7677492 tiger /mydrive/base/tiger/tiger.carton.8.png
# 0.7661456 larue /mydrive/base/larue/larue.carton.3.png
# 0.7624319 heineken /mydrive/base/heineken/heineken.carton.7.png
# 0.7405869 heineken /mydrive/base/heineken/heineken.carton.3.png
# EXPECTED: tiger               GOT: tiger
# 0.9999997 heineken /mydrive/base/heineken/heineken.carton.9.png
# 0.78383875 biaviet /mydrive/base/biaviet/biaviet.carton.3.png
# 0.76666224 heineken /mydrive/base/heineken/heineken.carton.1.jpeg
# 0.7653926 heineken /mydrive/base/heineken/heineken.carton.2.png
# 0.7587472 tiger /mydrive/base/tiger/tiger.carton.5.png
# EXPECTED: heineken            GOT: heineken
# 1.0 tiger /mydrive/base/tiger/tiger.carton.5.png
# 0.83502424 heineken /mydrive/base/heineken/heineken.carton.2.png
# 0.819672 biaviet /mydrive/base/biaviet/biaviet.carton.4.png
# 0.79540527 tiger /mydrive/base/tiger/tiger.carton.7.png
# 0.78863204 tiger /mydrive/base/tiger/tiger.carton.2.png
# EXPECTED: tiger               GOT: tiger
# 0.8932204 tiger /mydrive/base/tiger/tiger.carton.4.png
# 0.88901293 heineken /mydrive/base/heineken/heineken.carton.3.png
# 0.88196206 heineken /mydrive/base/heineken/heineken.carton.4.png
# 0.8702334 tiger /mydrive/base/tiger/tiger.carton.7.png
# 0.8677176 biaviet /mydrive/base/biaviet/biaviet.carton.4.png
# EXPECTED: heineken            GOT: tiger
# 0.99999964 tiger /mydrive/base/tiger/tiger.carton.8.png
# 0.8190819 larue /mydrive/base/larue/larue.carton.9.png
# 0.80881447 tiger /mydrive/base/tiger/tiger.carton.2.png
# 0.8015777 heineken /mydrive/base/heineken/heineken.carton.7.png
# 0.7944934 tiger /mydrive/base/tiger/tiger.carton.13.png
# EXPECTED: tiger               GOT: tiger
# 0.8332762 tiger /mydrive/base/tiger/tiger.carton.4.png
# 0.82808024 heineken /mydrive/base/heineken/heineken.carton.3.png
# 0.81918687 larue /mydrive/base/larue/larue.carton.2.png
# 0.8081337 tiger /mydrive/base/tiger/tiger.carton.9.png
# 0.8063014 heineken /mydrive/base/heineken/heineken.carton.2.png
# EXPECTED: biaviet             GOT: tiger
# 0.9282119 larue /mydrive/base/larue/larue.carton.7.png
# 0.9033505 larue /mydrive/base/larue/larue.carton.5.png
# 0.89630246 larue /mydrive/base/larue/larue.carton.8.png
# 0.84297603 bivina /mydrive/base/bivina/bivina.carton.6.png
# 0.8354026 bivina /mydrive/base/bivina/bivina.carton.7.png
# EXPECTED: larue               GOT: larue
# 0.9999999 bivina /mydrive/base/bivina/bivina.carton.6.png
# 0.92641675 bivina /mydrive/base/bivina/bivina.carton.7.png
# 0.9089606 bivina /mydrive/base/bivina/bivina.carton.5.png
# 0.8876369 bivina /mydrive/base/bivina/bivina.carton.3.png
# 0.8707839 heineken /mydrive/base/heineken/heineken.carton.4.png
# EXPECTED: bivina              GOT: bivina
# 0.99999994 larue /mydrive/base/larue/larue.carton.5.png
# 0.94158787 larue /mydrive/base/larue/larue.carton.7.png
# 0.9094232 larue /mydrive/base/larue/larue.carton.8.png
# 0.8689467 bivina /mydrive/base/bivina/bivina.carton.6.png
# 0.8673322 larue /mydrive/base/larue/larue.carton.2.png
# EXPECTED: larue               GOT: larue
# 0.9999997 heineken /mydrive/base/heineken/heineken.carton.7.png
# 0.8449807 heineken /mydrive/base/heineken/heineken.carton.3.png
# 0.8068835 heineken /mydrive/base/heineken/heineken.carton.8.png
# 0.8015777 tiger /mydrive/base/tiger/tiger.carton.8.png
# 0.79558265 heineken /mydrive/base/heineken/heineken.carton.2.png
# EXPECTED: heineken            GOT: heineken
# 1.0000002 heineken /mydrive/base/heineken/heineken.can.4.png
# 0.8855908 heineken /mydrive/base/heineken/heineken.can.3.png
# 0.8471786 tiger /mydrive/base/tiger/tiger.can.2.png
# 0.81984645 biaviet /mydrive/base/biaviet/biaviet.can.5.png
# 0.818568 heineken /mydrive/base/heineken/heineken.can.6.png
# EXPECTED: heineken            GOT: heineken
# 0.7468685 heineken /mydrive/base/heineken/heineken.bottle.2.png
# 0.7340901 biaviet /mydrive/base/biaviet/biaviet.bottle.2.png
# 0.7319016 heineken /mydrive/base/heineken/heineken.bottle.3.png
# 0.7240267 biaviet /mydrive/base/biaviet/biaviet.bottle.1.png
# 0.7125683 biaviet /mydrive/base/biaviet/biaviet.bottle.4.png
# EXPECTED: biaviet             GOT: biaviet
# 0.76437193 biaviet /mydrive/base/biaviet/biaviet.bottle.2.png
# 0.7498648 heineken /mydrive/base/heineken/heineken.bottle.3.png
# 0.74818206 biaviet /mydrive/base/biaviet/biaviet.bottle.1.png
# 0.7391652 heineken /mydrive/base/heineken/heineken.bottle.2.png
# 0.73333955 biaviet /mydrive/base/biaviet/biaviet.bottle.4.png
# EXPECTED: biaviet             GOT: biaviet
# 0.883312 biaviet /mydrive/base/biaviet/biaviet.carton.6.png
# 0.78870237 bivina /mydrive/base/bivina/bivina.carton.6.png
# 0.78739476 heineken /mydrive/base/heineken/heineken.carton.8.png
# 0.78284395 heineken /mydrive/base/heineken/heineken.carton.7.png
# 0.7823617 larue /mydrive/base/larue/larue.carton.11.png
# EXPECTED: biaviet             GOT: heineken
# 1.0 biaviet /mydrive/base/biaviet/biaviet.carton.6.png
# 0.8030421 biaviet /mydrive/base/biaviet/biaviet.carton.1.png
# 0.7999906 larue /mydrive/base/larue/larue.carton.11.png
# 0.79662585 bivina /mydrive/base/bivina/bivina.carton.6.png
# 0.79260945 biaviet /mydrive/base/biaviet/biaviet.carton.2.png
# EXPECTED: biaviet             GOT: biaviet
# 0.82966906 bivina /mydrive/base/bivina/bivina.banner.4.png
# 0.820434 heineken /mydrive/base/heineken/heineken.banner.1.jpeg
# 0.8182877 bivina /mydrive/base/bivina/bivina.banner.1.png
# 0.8024293 biaviet /mydrive/base/biaviet/biaviet.banner.2.png
# 0.7998774 biaviet /mydrive/base/biaviet/biaviet.banner.1.png
# EXPECTED: biaviet             GOT: bivina
# 1.0 larue /mydrive/base/larue/larue.can.1.png
# 0.887296 larue /mydrive/base/larue/larue.can.3.png
# 0.838716 larue /mydrive/base/larue/larue.can.4.png
# 0.83730114 biaviet /mydrive/base/biaviet/biaviet.can.4.png
# 0.7960448 heineken /mydrive/base/heineken/heineken.can.3.png
# EXPECTED: larue               GOT: larue
# 0.9999999 tiger /mydrive/base/tiger/tiger.icebucket.2.png
# 0.85565335 larue /mydrive/base/larue/larue.icebucket.1.png
# 0.83750564 tiger /mydrive/base/tiger/tiger.icebucket.1.png
# 0.80105233 biaviet /mydrive/base/biaviet/biaviet.icebucket.6.png
# 0.77708364 tiger /mydrive/base/tiger/tiger.icebucket.4.png
# EXPECTED: tiger               GOT: tiger
# 1.0000004 tiger /mydrive/base/tiger/tiger.icebox.1.png
# 0.9757236 tiger /mydrive/base/tiger/tiger.icebox.4.png
# 0.8454569 tiger /mydrive/base/tiger/tiger.icebox.3.png
# 0.8304241 larue /mydrive/base/larue/larue.icebox.1.png
# 0.7668862 tiger /mydrive/base/tiger/tiger.icebox.2.jpeg
# EXPECTED: tiger               GOT: tiger
# 1.0000001 biaviet /mydrive/base/biaviet/biaviet.can.4.png
# 0.849664 larue /mydrive/base/larue/larue.can.3.png
# 0.8373383 biaviet /mydrive/base/biaviet/biaviet.can.3.png
# 0.83730114 larue /mydrive/base/larue/larue.can.1.png
# 0.831414 heineken /mydrive/base/heineken/heineken.can.5.png
# EXPECTED: biaviet             GOT: biaviet
# 0.81333107 biaviet /mydrive/base/biaviet/biaviet.carton.4.png
# 0.8108266 tiger /mydrive/base/tiger/tiger.carton.2.png
# 0.80790126 heineken /mydrive/base/heineken/heineken.carton.4.png
# 0.80588496 bivina /mydrive/base/bivina/bivina.carton.6.png
# 0.80354804 biaviet /mydrive/base/biaviet/biaviet.carton.1.png
# EXPECTED: biaviet             GOT: biaviet
# 1.0000002 tiger /mydrive/base/tiger/tiger.can.2.png
# 0.8471786 heineken /mydrive/base/heineken/heineken.can.4.png
# 0.83609295 larue /mydrive/base/larue/larue.can.4.png
# 0.80269474 biaviet /mydrive/base/biaviet/biaviet.can.5.png
# 0.797914 heineken /mydrive/base/heineken/heineken.can.3.png
# EXPECTED: tiger               GOT: heineken
# 0.75230426 larue /mydrive/base/larue/larue.logo.1.jpg
# 0.7491747 larue /mydrive/base/larue/larue.logo.2.jpg
# 0.7031106 bivina /mydrive/base/bivina/bivina.logo.1.jpg
# 0.696174 bivina /mydrive/base/bivina/bivina.logo.3.png
# 0.684821 bivina /mydrive/base/bivina/bivina.logo.2.jpg
# EXPECTED: heineken            GOT: bivina
# 1.0 tiger /mydrive/base/tiger/tiger.banner.7.png
# 0.7636026 larue /mydrive/base/larue/larue.logo.2.jpg
# 0.75394225 tiger /mydrive/base/tiger/tiger.banner.1.png
# 0.7527673 tiger /mydrive/base/tiger/tiger.banner.6.jpg
# 0.7518103 biaviet /mydrive/base/biaviet/biaviet.banner.2.png
# EXPECTED: tiger               GOT: tiger
# 1.0000001 tiger /mydrive/base/tiger/tiger.can.3.png
# 0.85067105 tiger /mydrive/base/tiger/tiger.can.4.png
# 0.82914066 heineken /mydrive/base/heineken/heineken.can.5.png
# 0.8179202 larue /mydrive/base/larue/larue.can.3.png
# 0.784235 tiger /mydrive/base/tiger/tiger.can.5.png
# EXPECTED: tiger               GOT: tiger
# 0.9260886 tiger /mydrive/base/tiger/tiger.bottle.1.png
# 0.83903015 tiger /mydrive/base/tiger/tiger.bottle.14.png
# 0.8150659 tiger /mydrive/base/tiger/tiger.bottle.6.png
# 0.8104167 tiger /mydrive/base/tiger/tiger.bottle.12.png
# 0.80146 tiger /mydrive/base/tiger/tiger.bottle.2.png
# EXPECTED: tiger               GOT: tiger
# 0.99999964 tiger /mydrive/base/tiger/tiger.bottle.6.png
# 0.86963546 tiger /mydrive/base/tiger/tiger.bottle.11.png
# 0.8298529 tiger /mydrive/base/tiger/tiger.bottle.14.png
# 0.82693803 tiger /mydrive/base/tiger/tiger.bottle.7.png
# 0.7963221 tiger /mydrive/base/tiger/tiger.bottle.1.png
# EXPECTED: tiger               GOT: tiger
# 1.0 biaviet /mydrive/base/biaviet/biaviet.carton.1.png
# 0.85447 biaviet /mydrive/base/biaviet/biaviet.carton.4.png
# 0.8313883 bivina /mydrive/base/bivina/bivina.carton.1.png
# 0.82577115 bivina /mydrive/base/bivina/bivina.carton.4.png
# 0.8188652 biaviet /mydrive/base/biaviet/biaviet.carton.5.png
# EXPECTED: biaviet             GOT: biaviet
# 1.0000001 biaviet /mydrive/base/biaviet/biaviet.carton.2.png
# 0.841026 biaviet /mydrive/base/biaviet/biaviet.carton.4.png
# 0.83457327 biaviet /mydrive/base/biaviet/biaviet.carton.5.png
# 0.8328102 bivina /mydrive/base/bivina/bivina.carton.3.png
# 0.82151043 biaviet /mydrive/base/biaviet/biaviet.carton.3.png
# EXPECTED: biaviet             GOT: biaviet
# 0.7468685 heineken /mydrive/base/heineken/heineken.bottle.2.png
# 0.7340901 biaviet /mydrive/base/biaviet/biaviet.bottle.2.png
# 0.7319016 heineken /mydrive/base/heineken/heineken.bottle.3.png
# 0.7240267 biaviet /mydrive/base/biaviet/biaviet.bottle.1.png
# 0.7125683 biaviet /mydrive/base/biaviet/biaviet.bottle.4.png
# EXPECTED: biaviet             GOT: biaviet
# 0.9999999 larue /mydrive/base/larue/larue.icebox.3.png
# 0.8107793 larue /mydrive/base/larue/larue.icebox.2.jpeg
# 0.74314463 tiger /mydrive/base/tiger/tiger.icebox.3.png
# 0.73223317 biaviet /mydrive/base/biaviet/biaviet.icebox.1.png
# 0.7186428 tiger /mydrive/base/tiger/tiger.icebox.1.png
# EXPECTED: larue               GOT: larue
# 1.0 heineken /mydrive/base/heineken/heineken.carton.2.png
# 0.8649119 tiger /mydrive/base/tiger/tiger.carton.7.png
# 0.8601546 biaviet /mydrive/base/biaviet/biaviet.carton.4.png
# 0.8381828 heineken /mydrive/base/heineken/heineken.carton.3.png
# 0.83502424 tiger /mydrive/base/tiger/tiger.carton.5.png
# EXPECTED: heineken            GOT: heineken
# 0.8100656 heineken /mydrive/base/heineken/heineken.banner.6.png
# 0.79219913 edelweiss /mydrive/base/edelweiss/edelweiss.banner.1.jpg
# 0.78254473 biaviet /mydrive/base/biaviet/biaviet.banner.1.png
# 0.7714569 tiger /mydrive/base/tiger/tiger.banner.6.jpg
# 0.7533313 bivina /mydrive/base/bivina/bivina.banner.1.png
# EXPECTED: heineken            GOT: heineken
# 0.77064824 biaviet /mydrive/base/biaviet/biaviet.bottle.2.png
# 0.7672682 heineken /mydrive/base/heineken/heineken.bottle.3.png
# 0.7370213 biaviet /mydrive/base/biaviet/biaviet.bottle.1.png
# 0.7345146 heineken /mydrive/base/heineken/heineken.bottle.2.png
# 0.7086678 biaviet /mydrive/base/biaviet/biaviet.bottle.4.png
# EXPECTED: biaviet             GOT: biaviet
# 0.99999994 larue /mydrive/base/larue/larue.carton.3.png
# 0.8135674 larue /mydrive/base/larue/larue.carton.5.png
# 0.8107612 larue /mydrive/base/larue/larue.carton.7.png
# 0.8047281 heineken /mydrive/base/heineken/heineken.carton.8.png
# 0.8012674 heineken /mydrive/base/heineken/heineken.carton.3.png
# EXPECTED: larue               GOT: larue
# 1.0000005 larue /mydrive/base/larue/larue.carton.2.png
# 0.8811155 heineken /mydrive/base/heineken/heineken.carton.3.png
# 0.8673322 larue /mydrive/base/larue/larue.carton.5.png
# 0.86164767 larue /mydrive/base/larue/larue.carton.4.png
# 0.860226 larue /mydrive/base/larue/larue.carton.7.png
# EXPECTED: larue               GOT: larue
# 1.0 larue /mydrive/base/larue/larue.carton.4.png
# 0.86164767 larue /mydrive/base/larue/larue.carton.2.png
# 0.856773 bivina /mydrive/base/bivina/bivina.carton.3.png
# 0.8475881 bivina /mydrive/base/bivina/bivina.carton.4.png
# 0.8308174 biaviet /mydrive/base/biaviet/biaviet.carton.4.png
# EXPECTED: larue               GOT: larue
# 1.0000002 larue /mydrive/base/larue/larue.carton.8.png
# 0.9103655 larue /mydrive/base/larue/larue.carton.7.png
# 0.90942323 larue /mydrive/base/larue/larue.carton.5.png
# 0.8641916 bivina /mydrive/base/bivina/bivina.carton.6.png
# 0.84763956 bivina /mydrive/base/bivina/bivina.carton.7.png
# EXPECTED: larue               GOT: larue
# 0.65561855 biaviet /mydrive/base/biaviet/biaviet.logo.2.png
# 0.63805556 bivina /mydrive/base/bivina/bivina.logo.3.png
# 0.6093899 biaviet /mydrive/base/biaviet/biaviet.logo.1.jpg
# 0.59245396 heineken /mydrive/base/heineken/heineken.logo.2.jpg
# 0.5921139 bivina /mydrive/base/bivina/bivina.logo.1.jpg
# EXPECTED: larue               GOT: biaviet
# 1.0 tiger /mydrive/base/tiger/tiger.carton.11.png
# 0.8292763 heineken /mydrive/base/heineken/heineken.carton.4.png
# 0.82437813 tiger /mydrive/base/tiger/tiger.carton.2.png
# 0.82315624 tiger /mydrive/base/tiger/tiger.carton.7.png
# 0.8120254 larue /mydrive/base/larue/larue.carton.8.png
# EXPECTED: tiger               GOT: tiger
# 0.9999999 bivina /mydrive/base/bivina/bivina.carton.5.png
# 0.9089606 bivina /mydrive/base/bivina/bivina.carton.6.png
# 0.90744644 bivina /mydrive/base/bivina/bivina.carton.3.png
# 0.9017217 bivina /mydrive/base/bivina/bivina.carton.7.png
# 0.85340166 biaviet /mydrive/base/biaviet/biaviet.carton.4.png
# EXPECTED: bivina              GOT: bivina
# 0.9999999 bivina /mydrive/base/bivina/bivina.carton.4.png
# 0.89140993 bivina /mydrive/base/bivina/bivina.carton.3.png
# 0.8707666 bivina /mydrive/base/bivina/bivina.carton.7.png
# 0.8559127 bivina /mydrive/base/bivina/bivina.carton.6.png
# 0.84904665 bivina /mydrive/base/bivina/bivina.carton.5.png
# EXPECTED: bivina              GOT: bivina
# 1.0000002 heineken /mydrive/base/heineken/heineken.carton.3.png
# 0.8833808 tiger /mydrive/base/tiger/tiger.carton.7.png
# 0.8811155 larue /mydrive/base/larue/larue.carton.2.png
# 0.8667103 tiger /mydrive/base/tiger/tiger.carton.4.png
# 0.8451401 tiger /mydrive/base/tiger/tiger.carton.6.png
# EXPECTED: heineken            GOT: tiger
# 1.0 larue /mydrive/base/larue/larue.banner.2.png
# 0.7737357 biaviet /mydrive/base/biaviet/biaviet.banner.6.png
# 0.7704881 bivina /mydrive/base/bivina/bivina.banner.2.png
# 0.7695925 larue /mydrive/base/larue/larue.banner.3.png
# 0.7539296 heineken /mydrive/base/heineken/heineken.banner.3.png
# EXPECTED: larue               GOT: larue
# 0.99999994 heineken /mydrive/base/heineken/heineken.carton.4.png
# 0.8707839 bivina /mydrive/base/bivina/bivina.carton.6.png
# 0.8501524 tiger /mydrive/base/tiger/tiger.carton.4.png
# 0.84498775 heineken /mydrive/base/heineken/heineken.carton.3.png
# 0.8433979 bivina /mydrive/base/bivina/bivina.carton.5.png
# EXPECTED: heineken            GOT: heineken
# 0.8789445 tiger /mydrive/base/tiger/tiger.carton.11.png
# 0.84442323 bivina /mydrive/base/bivina/bivina.carton.6.png
# 0.8439051 bivina /mydrive/base/bivina/bivina.carton.4.png
# 0.84109974 larue /mydrive/base/larue/larue.carton.8.png
# 0.8375895 biaviet /mydrive/base/biaviet/biaviet.carton.4.png
# EXPECTED: tiger               GOT: bivina
# 0.99999964 heineken /mydrive/base/heineken/heineken.carton.5.png
# 0.8608674 heineken /mydrive/base/heineken/heineken.carton.8.png
# 0.83364785 larue /mydrive/base/larue/larue.carton.5.png
# 0.83351135 tiger /mydrive/base/tiger/tiger.carton.2.png
# 0.8312751 larue /mydrive/base/larue/larue.carton.11.png
# EXPECTED: heineken            GOT: heineken
# 1.0 tiger /mydrive/base/tiger/tiger.carton.1.png
# 0.7943697 larue /mydrive/base/larue/larue.carton.12.png
# 0.79223865 larue /mydrive/base/larue/larue.carton.6.png
# 0.7813633 biaviet /mydrive/base/biaviet/biaviet.carton.1.png
# 0.7796214 larue /mydrive/base/larue/larue.carton.10.png
# EXPECTED: tiger               GOT: larue
# 1.0 larue /mydrive/base/larue/larue.banner.3.png
# 0.8179041 heineken /mydrive/base/heineken/heineken.banner.3.png
# 0.81620574 tiger /mydrive/base/tiger/tiger.banner.3.png
# 0.81608826 heineken /mydrive/base/heineken/heineken.banner.2.png
# 0.7896148 larue /mydrive/base/larue/larue.banner.4.png
# EXPECTED: larue               GOT: larue
# 0.99999976 tiger /mydrive/base/tiger/tiger.bottle.13.png
# 0.8232952 tiger /mydrive/base/tiger/tiger.bottle.5.png
# 0.80666006 tiger /mydrive/base/tiger/tiger.bottle.4.png
# 0.8002678 tiger /mydrive/base/tiger/tiger.bottle.3.png
# 0.7545151 biaviet /mydrive/base/biaviet/biaviet.bottle.3.png
# EXPECTED: tiger               GOT: tiger
# 1.0 tiger /mydrive/base/tiger/tiger.carton.3.png
# 0.78160644 larue /mydrive/base/larue/larue.carton.9.png
# 0.77075803 tiger /mydrive/base/tiger/tiger.carton.8.png
# 0.76089764 larue /mydrive/base/larue/larue.carton.10.png
# 0.7567165 larue /mydrive/base/larue/larue.carton.6.png
# EXPECTED: tiger               GOT: larue
# 0.9999998 tiger /mydrive/base/tiger/tiger.bottle.7.png
# 0.82693803 tiger /mydrive/base/tiger/tiger.bottle.6.png
# 0.7877336 bivina /mydrive/base/bivina/bivina.bottle.1.png
# 0.78108615 tiger /mydrive/base/tiger/tiger.bottle.1.png
# 0.78006697 tiger /mydrive/base/tiger/tiger.bottle.10.png
# EXPECTED: tiger               GOT: tiger
# 0.99999994 tiger /mydrive/base/tiger/tiger.bottle.9.png
# 0.77429163 tiger /mydrive/base/tiger/tiger.bottle.7.png
# 0.7686733 tiger /mydrive/base/tiger/tiger.bottle.6.png
# 0.761325 tiger /mydrive/base/tiger/tiger.bottle.10.png
# 0.7449518 tiger /mydrive/base/tiger/tiger.bottle.12.png
# EXPECTED: tiger               GOT: tiger
# 0.99999994 heineken /mydrive/base/heineken/heineken.carton.6.png
# 0.81510866 heineken /mydrive/base/heineken/heineken.carton.8.png
# 0.749516 larue /mydrive/base/larue/larue.carton.5.png
# 0.74443376 heineken /mydrive/base/heineken/heineken.carton.3.png
# 0.7374829 tiger /mydrive/base/tiger/tiger.carton.8.png
# EXPECTED: heineken            GOT: heineken
# 1.0000002 tiger /mydrive/base/tiger/tiger.bottle.5.png
# 0.8232952 tiger /mydrive/base/tiger/tiger.bottle.13.png
# 0.8155624 biaviet /mydrive/base/biaviet/biaviet.bottle.3.png
# 0.802325 tiger /mydrive/base/tiger/tiger.bottle.12.png
# 0.7958344 tiger /mydrive/base/tiger/tiger.bottle.3.png
# EXPECTED: tiger               GOT: tiger
# 1.0000002 tiger /mydrive/base/tiger/tiger.carton.4.png
# 0.9501647 tiger /mydrive/base/tiger/tiger.carton.6.png
# 0.8721906 tiger /mydrive/base/tiger/tiger.carton.7.png
# 0.8667103 heineken /mydrive/base/heineken/heineken.carton.3.png
# 0.8501524 heineken /mydrive/base/heineken/heineken.carton.4.png
# EXPECTED: tiger               GOT: tiger
# 0.99999994 larue /mydrive/base/larue/larue.carton.7.png
# 0.94158775 larue /mydrive/base/larue/larue.carton.5.png
# 0.9103655 larue /mydrive/base/larue/larue.carton.8.png
# 0.8751121 tiger /mydrive/base/tiger/tiger.carton.2.png
# 0.8676442 bivina /mydrive/base/bivina/bivina.carton.6.png
# EXPECTED: larue               GOT: larue
# 0.8772423 heineken /mydrive/base/heineken/heineken.carton.7.png
# 0.85463536 tiger /mydrive/base/tiger/tiger.carton.2.png
# 0.8528685 bivina /mydrive/base/bivina/bivina.carton.6.png
# 0.8524891 heineken /mydrive/base/heineken/heineken.carton.4.png
# 0.84981465 heineken /mydrive/base/heineken/heineken.carton.2.png
# EXPECTED: heineken            GOT: heineken
# 0.99999994 tiger /mydrive/base/tiger/tiger.carton.2.png
# 0.8751124 larue /mydrive/base/larue/larue.carton.7.png
# 0.8443005 bivina /mydrive/base/bivina/bivina.carton.6.png
# 0.842591 larue /mydrive/base/larue/larue.carton.8.png
# 0.8393718 bivina /mydrive/base/bivina/bivina.carton.5.png
# EXPECTED: tiger               GOT: larue
# 0.99999994 bivina /mydrive/base/bivina/bivina.carton.3.png
# 0.91288316 bivina /mydrive/base/bivina/bivina.carton.7.png
# 0.90744644 bivina /mydrive/base/bivina/bivina.carton.5.png
# 0.89140993 bivina /mydrive/base/bivina/bivina.carton.4.png
# 0.8876369 bivina /mydrive/base/bivina/bivina.carton.6.png
# EXPECTED: bivina              GOT: bivina
# 0.9659034 biaviet /mydrive/base/biaviet/biaviet.carton.4.png
# 0.86758363 biaviet /mydrive/base/biaviet/biaviet.carton.5.png
# 0.8607749 bivina /mydrive/base/bivina/bivina.carton.3.png
# 0.84389204 heineken /mydrive/base/heineken/heineken.carton.2.png
# 0.84263223 biaviet /mydrive/base/biaviet/biaviet.carton.1.png
# EXPECTED: biaviet             GOT: biaviet
# 1.0 tiger /mydrive/base/tiger/tiger.carton.6.png
# 0.9501647 tiger /mydrive/base/tiger/tiger.carton.4.png
# 0.8729731 tiger /mydrive/base/tiger/tiger.carton.7.png
# 0.8451401 heineken /mydrive/base/heineken/heineken.carton.3.png
# 0.80969155 heineken /mydrive/base/heineken/heineken.carton.4.png
# EXPECTED: tiger               GOT: tiger
# 0.9999998 biaviet /mydrive/base/biaviet/biaviet.carton.4.png
# 0.8837104 bivina /mydrive/base/bivina/bivina.carton.3.png
# 0.8757556 biaviet /mydrive/base/biaviet/biaviet.carton.5.png
# 0.8601546 heineken /mydrive/base/heineken/heineken.carton.2.png
# 0.8559245 bivina /mydrive/base/bivina/bivina.carton.7.png
# EXPECTED: biaviet             GOT: biaviet
# 1.0000001 heineken /mydrive/base/heineken/heineken.can.1.png
# 0.80415154 heineken /mydrive/base/heineken/heineken.can.6.png
# 0.80065966 heineken /mydrive/base/heineken/heineken.can.2.png
# 0.7985419 biaviet /mydrive/base/biaviet/biaviet.can.4.png
# 0.78703976 heineken /mydrive/base/heineken/heineken.can.5.png
# EXPECTED: heineken            GOT: heineken
# 0.9999999 biaviet /mydrive/base/biaviet/biaviet.carton.5.png
# 0.8757556 biaviet /mydrive/base/biaviet/biaviet.carton.4.png
# 0.83457327 biaviet /mydrive/base/biaviet/biaviet.carton.2.png
# 0.8188652 biaviet /mydrive/base/biaviet/biaviet.carton.1.png
# 0.8118449 bivina /mydrive/base/bivina/bivina.carton.3.png
# EXPECTED: biaviet             GOT: biaviet
# 0.8424766 biaviet /mydrive/base/biaviet/biaviet.bottle.2.png
# 0.82166016 biaviet /mydrive/base/biaviet/biaviet.bottle.1.png
# 0.81334597 biaviet /mydrive/base/biaviet/biaviet.bottle.3.png
# 0.8055279 biaviet /mydrive/base/biaviet/biaviet.bottle.5.png
# 0.7599945 tiger /mydrive/base/tiger/tiger.bottle.12.png
# EXPECTED: biaviet             GOT: biaviet
# 1.0 biaviet /mydrive/base/biaviet/biaviet.bottle.3.png
# 0.829321 tiger /mydrive/base/tiger/tiger.bottle.12.png
# 0.8155624 tiger /mydrive/base/tiger/tiger.bottle.5.png
# 0.81226313 biaviet /mydrive/base/biaviet/biaviet.bottle.5.png
# 0.8051263 biaviet /mydrive/base/biaviet/biaviet.bottle.1.png
# EXPECTED: biaviet             GOT: biaviet
# 0.6807314 larue /mydrive/base/larue/larue.logo.1.jpg
# 0.66209793 larue /mydrive/base/larue/larue.logo.2.jpg
# 0.6515385 bivina /mydrive/base/bivina/bivina.logo.3.png
# 0.64296305 tiger /mydrive/base/tiger/tiger.logo.2.jpg
# 0.6311487 bivina /mydrive/base/bivina/bivina.logo.1.jpg
# EXPECTED: biaviet             GOT: larue
# 1.0 biaviet /mydrive/base/biaviet/biaviet.can.3.png
# 0.8373383 biaviet /mydrive/base/biaviet/biaviet.can.4.png
# 0.79482347 larue /mydrive/base/larue/larue.can.3.png
# 0.79119796 biaviet /mydrive/base/biaviet/biaviet.can.5.png
# 0.78454375 tiger /mydrive/base/tiger/tiger.can.1.png
# EXPECTED: biaviet             GOT: biaviet
# 0.99999976 biaviet /mydrive/base/biaviet/biaviet.can.1.png
# 0.7426405 biaviet /mydrive/base/biaviet/biaviet.can.3.png
# 0.7260541 heineken /mydrive/base/heineken/heineken.can.5.png
# 0.72022533 biaviet /mydrive/base/biaviet/biaviet.can.4.png
# 0.71473265 biaviet /mydrive/base/biaviet/biaviet.can.2.png
# EXPECTED: biaviet             GOT: biaviet
# 0.9999999 larue /mydrive/base/larue/larue.icebucket.1.png
# 0.86698616 biaviet /mydrive/base/biaviet/biaviet.icebucket.3.png
# 0.85565335 tiger /mydrive/base/tiger/tiger.icebucket.2.png
# 0.8472438 biaviet /mydrive/base/biaviet/biaviet.icebucket.6.png
# 0.8049225 tiger /mydrive/base/tiger/tiger.icebucket.1.png
# EXPECTED: larue               GOT: biaviet
# 0.9999999 larue /mydrive/base/larue/larue.icebox.1.png
# 0.8413 larue /mydrive/base/larue/larue.icebox.4.png
# 0.8329315 tiger /mydrive/base/tiger/tiger.icebox.4.png
# 0.8304241 tiger /mydrive/base/tiger/tiger.icebox.1.png
# 0.8172109 tiger /mydrive/base/tiger/tiger.icebox.3.png
# EXPECTED: larue               GOT: tiger
# 0.79457235 heineken /mydrive/base/heineken/heineken.logo.2.jpg
# 0.7730972 biaviet /mydrive/base/biaviet/biaviet.logo.1.jpg
# 0.77140456 heineken /mydrive/base/heineken/heineken.logo.3.jpg
# 0.76879656 biaviet /mydrive/base/biaviet/biaviet.logo.2.png
# 0.75812155 biaviet /mydrive/base/biaviet/biaviet.banner.2.png
# EXPECTED: biaviet             GOT: biaviet
# 0.9999999 heineken /mydrive/base/heineken/heineken.carton.8.png
# 0.8608674 heineken /mydrive/base/heineken/heineken.carton.5.png
# 0.8447454 larue /mydrive/base/larue/larue.carton.5.png
# 0.83597183 heineken /mydrive/base/heineken/heineken.carton.3.png
# 0.8297249 larue /mydrive/base/larue/larue.carton.11.png
# EXPECTED: heineken            GOT: heineken
# 0.8097155 heineken /mydrive/base/heineken/heineken.carton.4.png
# 0.7979783 heineken /mydrive/base/heineken/heineken.carton.3.png
# 0.78801143 heineken /mydrive/base/heineken/heineken.carton.2.png
# 0.78026974 larue /mydrive/base/larue/larue.carton.3.png
# 0.764608 bivina /mydrive/base/bivina/bivina.carton.6.png
# EXPECTED: heineken            GOT: heineken
# 0.78339 biaviet /mydrive/base/biaviet/biaviet.logo.1.jpg
# 0.76633537 heineken /mydrive/base/heineken/heineken.logo.2.jpg
# 0.76193047 biaviet /mydrive/base/biaviet/biaviet.logo.2.png
# 0.7307167 larue /mydrive/base/larue/larue.logo.1.jpg
# 0.7130319 bivina /mydrive/base/bivina/bivina.logo.1.jpg
# EXPECTED: biaviet             GOT: biaviet
# 0.99999964 tiger /mydrive/base/tiger/tiger.carton.9.png
# 0.8054018 tiger /mydrive/base/tiger/tiger.carton.4.png
# 0.798131 heineken /mydrive/base/heineken/heineken.carton.3.png
# 0.797601 larue /mydrive/base/larue/larue.carton.2.png
# 0.7914678 larue /mydrive/base/larue/larue.carton.9.png
# EXPECTED: tiger               GOT: tiger
# 1.0 tiger /mydrive/base/tiger/tiger.bottle.11.png
# 0.86963546 tiger /mydrive/base/tiger/tiger.bottle.6.png
# 0.8216342 tiger /mydrive/base/tiger/tiger.bottle.10.png
# 0.76328707 tiger /mydrive/base/tiger/tiger.bottle.7.png
# 0.75505215 biaviet /mydrive/base/biaviet/biaviet.bottle.2.png
# EXPECTED: tiger               GOT: tiger
# 0.7622967 biaviet /mydrive/base/biaviet/biaviet.bottle.2.png
# 0.7527089 biaviet /mydrive/base/biaviet/biaviet.bottle.4.png
# 0.7516056 tiger /mydrive/base/tiger/tiger.bottle.9.png
# 0.74793273 biaviet /mydrive/base/biaviet/biaviet.bottle.5.png
# 0.74474066 biaviet /mydrive/base/biaviet/biaviet.bottle.1.png
# EXPECTED: biaviet             GOT: biaviet
# 1.0 biaviet /mydrive/base/biaviet/biaviet.icebucket.3.png
# 0.86698616 larue /mydrive/base/larue/larue.icebucket.1.png
# 0.85964817 biaviet /mydrive/base/biaviet/biaviet.icebucket.5.png
# 0.8439522 tiger /mydrive/base/tiger/tiger.icebucket.4.png
# 0.8226052 biaviet /mydrive/base/biaviet/biaviet.icebucket.4.png
# EXPECTED: biaviet             GOT: biaviet
# 1.0000002 biaviet /mydrive/base/biaviet/biaviet.bottle.4.png
# 0.81166995 biaviet /mydrive/base/biaviet/biaviet.bottle.2.png
# 0.76003724 biaviet /mydrive/base/biaviet/biaviet.bottle.1.png
# 0.7325731 biaviet /mydrive/base/biaviet/biaviet.bottle.5.png
# 0.722795 biaviet /mydrive/base/biaviet/biaviet.bottle.3.png
# EXPECTED: biaviet             GOT: biaviet
# 0.99999994 tiger /mydrive/base/tiger/tiger.icebucket.3.png
# 0.85329676 tiger /mydrive/base/tiger/tiger.icebucket.4.png
# 0.8333664 tiger /mydrive/base/tiger/tiger.icebucket.1.png
# 0.80308115 biaviet /mydrive/base/biaviet/biaviet.icebucket.6.png
# 0.7919967 biaviet /mydrive/base/biaviet/biaviet.icebucket.4.png
# EXPECTED: tiger               GOT: tiger
# 1.0000001 tiger /mydrive/base/tiger/tiger.banner.2.png
# 0.9669696 tiger /mydrive/base/tiger/tiger.banner.8.png
# 0.8167726 tiger /mydrive/base/tiger/tiger.banner.3.png
# 0.7985145 tiger /mydrive/base/tiger/tiger.banner.1.png
# 0.78941643 heineken /mydrive/base/heineken/heineken.banner.3.png
# EXPECTED: tiger               GOT: tiger
# 0.8117405 biaviet /mydrive/base/biaviet/biaviet.carton.5.png
# 0.78853905 bivina /mydrive/base/bivina/bivina.carton.3.png
# 0.78663146 heineken /mydrive/base/heineken/heineken.carton.1.jpeg
# 0.78248936 biaviet /mydrive/base/biaviet/biaviet.carton.3.png
# 0.77903134 bivina /mydrive/base/bivina/bivina.carton.4.png
# EXPECTED: biaviet             GOT: biaviet
# 1.0 heineken /mydrive/base/heineken/heineken.icebucket.2.png
# 0.8026483 biaviet /mydrive/base/biaviet/biaviet.icebucket.6.png
# 0.8016391 biaviet /mydrive/base/biaviet/biaviet.icebucket.4.png
# 0.79782957 larue /mydrive/base/larue/larue.icebucket.1.png
# 0.7665689 tiger /mydrive/base/tiger/tiger.icebucket.2.png
# EXPECTED: heineken            GOT: biaviet
# 1.0000002 tiger /mydrive/base/tiger/tiger.icebucket.1.png
# 0.83750564 tiger /mydrive/base/tiger/tiger.icebucket.2.png
# 0.8333664 tiger /mydrive/base/tiger/tiger.icebucket.3.png
# 0.8279147 tiger /mydrive/base/tiger/tiger.icebucket.4.png
# 0.8049225 larue /mydrive/base/larue/larue.icebucket.1.png
# EXPECTED: tiger               GOT: tiger
# 1.0000001 biaviet /mydrive/base/biaviet/biaviet.icebucket.2.png
# 0.800475 biaviet /mydrive/base/biaviet/biaviet.icebucket.5.png
# 0.78641474 biaviet /mydrive/base/biaviet/biaviet.icebucket.6.png
# 0.7841592 tiger /mydrive/base/tiger/tiger.icebucket.4.png
# 0.7834774 biaviet /mydrive/base/biaviet/biaviet.icebucket.4.png
# EXPECTED: biaviet             GOT: biaviet
# 0.8166306 biaviet /mydrive/base/biaviet/biaviet.carton.3.png
# 0.786901 larue /mydrive/base/larue/larue.carton.10.png
# 0.7832838 biaviet /mydrive/base/biaviet/biaviet.carton.5.png
# 0.7715414 larue /mydrive/base/larue/larue.carton.6.png
# 0.76886964 biaviet /mydrive/base/biaviet/biaviet.carton.1.png
# EXPECTED: biaviet             GOT: biaviet
# 1.0 biaviet /mydrive/base/biaviet/biaviet.bottle.1.png
# 0.81702423 biaviet /mydrive/base/biaviet/biaviet.bottle.2.png
# 0.8051263 biaviet /mydrive/base/biaviet/biaviet.bottle.3.png
# 0.7939565 heineken /mydrive/base/heineken/heineken.bottle.2.png
# 0.76003724 biaviet /mydrive/base/biaviet/biaviet.bottle.4.png
# EXPECTED: biaviet             GOT: biaviet
# 0.8376069 biaviet /mydrive/base/biaviet/biaviet.banner.1.png
# 0.803238 biaviet /mydrive/base/biaviet/biaviet.banner.4.png
# 0.78446615 tiger /mydrive/base/tiger/tiger.banner.6.jpg
# 0.7808709 larue /mydrive/base/larue/larue.banner.1.jpeg
# 0.7607908 heineken /mydrive/base/heineken/heineken.banner.6.png
# EXPECTED: biaviet             GOT: biaviet
# 0.99999976 tiger /mydrive/base/tiger/tiger.banner.4.png
# 0.7628024 tiger /mydrive/base/tiger/tiger.banner.2.png
# 0.7485202 tiger /mydrive/base/tiger/tiger.banner.8.png
# 0.71622765 heineken /mydrive/base/heineken/heineken.banner.6.png
# 0.71223044 biaviet /mydrive/base/biaviet/biaviet.banner.5.png
# EXPECTED: tiger               GOT: tiger
# 0.99999994 biaviet /mydrive/base/biaviet/biaviet.bottle.2.png
# 0.82005954 biaviet /mydrive/base/biaviet/biaviet.bottle.5.png
# 0.81702423 biaviet /mydrive/base/biaviet/biaviet.bottle.1.png
# 0.81166995 biaviet /mydrive/base/biaviet/biaviet.bottle.4.png
# 0.79341346 biaviet /mydrive/base/biaviet/biaviet.bottle.3.png
# EXPECTED: biaviet             GOT: biaviet
# 1.0000002 biaviet /mydrive/base/biaviet/biaviet.banner.3.png
# 0.791311 biaviet /mydrive/base/biaviet/biaviet.banner.4.png
# 0.76938426 tiger /mydrive/base/tiger/tiger.banner.5.png
# 0.755582 biaviet /mydrive/base/biaviet/biaviet.banner.5.png
# 0.75557137 biaviet /mydrive/base/biaviet/biaviet.banner.1.png
# EXPECTED: biaviet             GOT: biaviet
# 0.9999999 tiger /mydrive/base/tiger/tiger.banner.5.png
# 0.7954724 heineken /mydrive/base/heineken/heineken.banner.5.jpeg
# 0.77687544 heineken /mydrive/base/heineken/heineken.banner.1.jpeg
# 0.76938426 biaviet /mydrive/base/biaviet/biaviet.banner.3.png
# 0.74761605 strongbow /mydrive/base/strongbow/strongbow.banner.1.jpeg
# EXPECTED: tiger               GOT: heineken
# 1.0000001 larue /mydrive/base/larue/larue.icebox.4.png
# 0.8413 larue /mydrive/base/larue/larue.icebox.1.png
# 0.7761388 tiger /mydrive/base/tiger/tiger.icebox.3.png
# 0.76926875 tiger /mydrive/base/tiger/tiger.icebox.4.png
# 0.764679 tiger /mydrive/base/tiger/tiger.icebox.1.png
# EXPECTED: larue               GOT: tiger
# 1.0 tiger /mydrive/base/tiger/tiger.bottle.10.png
# 0.8216342 tiger /mydrive/base/tiger/tiger.bottle.11.png
# 0.78006697 tiger /mydrive/base/tiger/tiger.bottle.7.png
# 0.7724291 tiger /mydrive/base/tiger/tiger.bottle.6.png
# 0.761325 tiger /mydrive/base/tiger/tiger.bottle.9.png
# EXPECTED: tiger               GOT: tiger
# 0.9999999 tiger /mydrive/base/tiger/tiger.carton.7.png
# 0.8833808 heineken /mydrive/base/heineken/heineken.carton.3.png
# 0.8729731 tiger /mydrive/base/tiger/tiger.carton.6.png
# 0.8721906 tiger /mydrive/base/tiger/tiger.carton.4.png
# 0.8649119 heineken /mydrive/base/heineken/heineken.carton.2.png
# EXPECTED: tiger               GOT: tiger
# 0.9999996 heineken /mydrive/base/heineken/heineken.can.2.png
# 0.80065966 heineken /mydrive/base/heineken/heineken.can.1.png
# 0.7929839 biaviet /mydrive/base/biaviet/biaviet.can.4.png
# 0.7871115 larue /mydrive/base/larue/larue.can.3.png
# 0.7782763 heineken /mydrive/base/heineken/heineken.can.5.png
# EXPECTED: heineken            GOT: heineken
# 0.89529777 biaviet /mydrive/base/biaviet/biaviet.can.2.png
# 0.86250544 biaviet /mydrive/base/biaviet/biaviet.can.4.png
# 0.812148 larue /mydrive/base/larue/larue.can.3.png
# 0.80323017 heineken /mydrive/base/heineken/heineken.can.1.png
# 0.8004908 heineken /mydrive/base/heineken/heineken.can.2.png
# EXPECTED: biaviet             GOT: biaviet
# 1.0000001 biaviet /mydrive/base/biaviet/biaviet.can.2.png
# 0.79646206 biaviet /mydrive/base/biaviet/biaviet.can.4.png
# 0.7831486 heineken /mydrive/base/heineken/heineken.can.1.png
# 0.75587916 heineken /mydrive/base/heineken/heineken.can.2.png
# 0.7509922 biaviet /mydrive/base/biaviet/biaviet.can.3.png
# EXPECTED: biaviet             GOT: biaviet
# 1.0 larue /mydrive/base/larue/larue.carton.6.png
# 0.96732354 larue /mydrive/base/larue/larue.carton.10.png
# 0.8700192 larue /mydrive/base/larue/larue.carton.12.png
# 0.8289178 bivina /mydrive/base/bivina/bivina.carton.1.png
# 0.8263807 heineken /mydrive/base/heineken/heineken.carton.1.jpeg
# EXPECTED: larue               GOT: larue
# 1.0000001 larue /mydrive/base/larue/larue.can.2.png
# 0.7555721 biaviet /mydrive/base/biaviet/biaviet.can.3.png
# 0.7426271 biaviet /mydrive/base/biaviet/biaviet.can.4.png
# 0.7340256 larue /mydrive/base/larue/larue.can.3.png
# 0.72896326 larue /mydrive/base/larue/larue.can.1.png
# EXPECTED: larue               GOT: larue
# 0.9201574 heineken /mydrive/base/heineken/heineken.carton.7.png
# 0.8672003 heineken /mydrive/base/heineken/heineken.carton.3.png
# 0.8486613 heineken /mydrive/base/heineken/heineken.carton.4.png
# 0.8377916 heineken /mydrive/base/heineken/heineken.carton.2.png
# 0.83149743 tiger /mydrive/base/tiger/tiger.carton.2.png
# EXPECTED: heineken            GOT: heineken
# 0.75504756 larue /mydrive/base/larue/larue.logo.2.jpg
# 0.75184464 larue /mydrive/base/larue/larue.logo.1.jpg
# 0.7432983 tiger /mydrive/base/tiger/tiger.logo.2.jpg
# 0.71041656 tiger /mydrive/base/tiger/tiger.logo.4.jpg
# 0.70162606 tiger /mydrive/base/tiger/tiger.logo.1.jpg
# EXPECTED: biaviet             GOT: tiger
# 1.0000001 tiger /mydrive/base/tiger/tiger.banner.1.png
# 0.85536104 biaviet /mydrive/base/biaviet/biaviet.banner.6.png
# 0.81367743 tiger /mydrive/base/tiger/tiger.banner.8.png
# 0.8122972 biaviet /mydrive/base/biaviet/biaviet.banner.5.png
# 0.80879253 bivina /mydrive/base/bivina/bivina.banner.2.png
# EXPECTED: tiger               GOT: tiger
# 1.0000002 tiger /mydrive/base/tiger/tiger.banner.3.png
# 0.8167726 tiger /mydrive/base/tiger/tiger.banner.2.png
# 0.81620574 larue /mydrive/base/larue/larue.banner.3.png
# 0.80090475 tiger /mydrive/base/tiger/tiger.banner.8.png
# 0.76743543 biaviet /mydrive/base/biaviet/biaviet.banner.5.png
# EXPECTED: tiger               GOT: tiger
# 0.69775665 larue /mydrive/base/larue/larue.logo.2.jpg
# 0.69120145 larue /mydrive/base/larue/larue.logo.1.jpg
# 0.6834216 tiger /mydrive/base/tiger/tiger.logo.4.jpg
# 0.6709075 tiger /mydrive/base/tiger/tiger.logo.2.jpg
# 0.6542877 tiger /mydrive/base/tiger/tiger.logo.3.jpg
# EXPECTED: biaviet             GOT: tiger
# 0.6983646 larue /mydrive/base/larue/larue.logo.2.jpg
# 0.6900301 larue /mydrive/base/larue/larue.logo.1.jpg
# 0.67061996 bivina /mydrive/base/bivina/bivina.logo.3.png
# 0.6448674 tiger /mydrive/base/tiger/tiger.logo.2.jpg
# 0.63900125 bivina /mydrive/base/bivina/bivina.logo.1.jpg
# EXPECTED: heineken            GOT: larue
# 1.0 heineken /mydrive/base/heineken/heineken.can.3.png
# 0.8855908 heineken /mydrive/base/heineken/heineken.can.4.png
# 0.8328997 heineken /mydrive/base/heineken/heineken.can.6.png
# 0.8224252 larue /mydrive/base/larue/larue.can.4.png
# 0.81547654 heineken /mydrive/base/heineken/heineken.can.5.png
# EXPECTED: heineken            GOT: heineken
# 1.0000001 biaviet /mydrive/base/biaviet/biaviet.carton.3.png
# 0.82151043 biaviet /mydrive/base/biaviet/biaviet.carton.2.png
# 0.78825957 biaviet /mydrive/base/biaviet/biaviet.carton.1.png
# 0.78383875 heineken /mydrive/base/heineken/heineken.carton.9.png
# 0.77520096 larue /mydrive/base/larue/larue.carton.10.png
# EXPECTED: biaviet             GOT: biaviet
# 0.8501327 biaviet /mydrive/base/biaviet/biaviet.banner.4.png
# 0.81851864 biaviet /mydrive/base/biaviet/biaviet.banner.3.png
# 0.8086968 biaviet /mydrive/base/biaviet/biaviet.banner.1.png
# 0.7806765 biaviet /mydrive/base/biaviet/biaviet.banner.5.png
# 0.7787045 tiger /mydrive/base/tiger/tiger.banner.1.png
# EXPECTED: biaviet             GOT: biaviet

# %%
trues = sum([1 for record in test_records if record[0]])
print(f"Accuracy: {trues}/{len(test_records)}")
# Out:
# Accuracy: 92/114
